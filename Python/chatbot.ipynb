# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Shahnawaz\Downloads\Learning_something\chatbot.venv\Scripts\python.exe

# %%
from qwen_wrapper import QwenClient

# %%
client = QwenClient()

# %%
prompt = "What is the current time?"

# %%
client.ask(prompt)
# Out:
# '00:03:06'
