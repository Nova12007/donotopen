# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Shahnawaz\Downloads\Learning_something\chatbot.venv\Scripts\python.exe

# %%
import ollama

# %%
import requests

r = requests.get("http://localhost:11434/api/tags")
print(r.json())
# Out:
# {'models': [{'name': 'qwen2.5-coder:7b', 'model': 'qwen2.5-coder:7b', 'modified_at': '2026-06-01T14:26:02.8569431+05:30', 'size': 4683087561, 'digest': 'dae161e27b0e90dd1856c8bb3209201fd6736d8eb66298e75ed87571486f4364', 'details': {'parent_model': '', 'format': 'gguf', 'family': 'qwen2', 'families': ['qwen2'], 'parameter_size': '7.6B', 'quantization_level': 'Q4_K_M'}}]}

# %%
response = ollama.chat(
    model='qwen2.5-coder:7b',
    messages=[
        {
            'role': 'user',
            'content': 'Explain how AI works in 200 words'
        }
    ]
)

# %%
print(response['message']['content'])
# Out:
# Artificial Intelligence (AI) refers to the simulation of human intelligence processes that machines can perform, such as visual perception, speech recognition, decision-making, and translation between languages. This is achieved through various techniques including machine learning, natural language processing, computer vision, and robotics.
#
# In 200 words:
# - **Machine Learning**: Algorithms learn from data without being explicitly programmed, allowing them to improve over time.
# - **Deep Learning**: A subset of machine learning using neural networks with many layers to recognize patterns in complex data.
# - **Natural Language Processing (NLP)**: Enables machines to understand and interpret human language, crucial for tasks like translation, sentiment analysis, and voice recognition.
# - **Computer Vision**: Makes computers able to interpret and understand images and videos, essential for applications like facial recognition and autonomous vehicles.
#
# AI systems use these technologies to process data, identify patterns, make decisions, and perform tasks that typically require human intelligence. This automation helps in reducing errors, increasing efficiency, and enabling new applications across various industries.
